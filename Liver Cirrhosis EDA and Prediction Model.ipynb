# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('cirrhosis.csv')
print(df.shape)
df.head()
# Out:
# (418, 20)
#    ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0   1     400      D  D-penicillamine  21464   F       Y            Y       Y
# 1   2    4500      C  D-penicillamine  20617   F       N            Y       Y
# 2   3    1012      D  D-penicillamine  25594   M       N            N       N
# 3   4    1925      D  D-penicillamine  19994   F       N            Y       Y
# 4   5    1504     CL          Placebo  13918   F       N            Y       Y
#
#   Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0     Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1     N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2     S        1.4        176.0     3.48   210.0     516.0   96.10
# 3     S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4     N        3.4        279.0     3.53   143.0     671.0  113.15
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# 0          172.0      190.0         12.2    4.0
# 1           88.0      221.0         10.6    3.0
# 2           55.0      151.0         12.0    4.0
# 3           92.0      183.0         10.3    4.0
# 4           72.0      136.0         10.9    3.0

# %%
df["Age"] = (df["Age"]/365)
df["Age"] = df["Age"].astype("int64")

# %%
df.drop(['ID'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   N_Days         418 non-null    int64
#  1   Status         418 non-null    object
#  2   Drug           312 non-null    object
#  3   Age            418 non-null    int64
#  4   Sex            418 non-null    object
#  5   Ascites        312 non-null    object
#  6   Hepatomegaly   312 non-null    object
#  7   Spiders        312 non-null    object
#  8   Edema          418 non-null    object
#  9   Bilirubin      418 non-null    float64
#  10  Cholesterol    284 non-null    float64
#  11  Albumin        418 non-null    float64
#  12  Copper         310 non-null    float64
#  13  Alk_Phos       312 non-null    float64
#  14  SGOT           312 non-null    float64
#  15  Tryglicerides  282 non-null    float64
#  16  Platelets      407 non-null    float64
#  17  Prothrombin    416 non-null    float64
#  18  Stage          412 non-null    float64
# dtypes: float64(10), int64(2), object(7)
# memory usage: 62.2+ KB

# %%
df.describe().transpose().style.background_gradient(cmap='GnBu')
# Out:
# <style type="text/css">
# #T_a260d_row0_col0, #T_a260d_row0_col4, #T_a260d_row0_col5, #T_a260d_row0_col6, #T_a260d_row1_col0, #T_a260d_row2_col0, #T_a260d_row4_col0, #T_a260d_row6_col1, #T_a260d_row6_col2, #T_a260d_row6_col3, #T_a260d_row6_col7 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_a260d_row0_col1 {
#   background-color: #084a8c;
#   color: #f1f1f1;
# }
# #T_a260d_row0_col2 {
#   background-color: #75c8c6;
#   color: #000000;
# }
# #T_a260d_row0_col3, #T_a260d_row9_col5 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_a260d_row0_col7 {
#   background-color: #b1e0b9;
#   color: #000000;
# }
# #T_a260d_row1_col1, #T_a260d_row7_col2 {
#   background-color: #f3faec;
#   color: #000000;
# }
# #T_a260d_row1_col2, #T_a260d_row1_col7, #T_a260d_row4_col3, #T_a260d_row10_col5 {
#   background-color: #f6fcef;
#   color: #000000;
# }
# #T_a260d_row1_col3 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_a260d_row1_col4, #T_a260d_row5_col4 {
#   background-color: #f1f9ea;
#   color: #000000;
# }
# #T_a260d_row1_col5, #T_a260d_row8_col2, #T_a260d_row10_col3 {
#   background-color: #f2faeb;
#   color: #000000;
# }
# #T_a260d_row1_col6 {
#   background-color: #f3fbed;
#   color: #000000;
# }
# #T_a260d_row2_col1, #T_a260d_row2_col2, #T_a260d_row2_col3, #T_a260d_row2_col4, #T_a260d_row2_col5, #T_a260d_row2_col6, #T_a260d_row2_col7, #T_a260d_row4_col1, #T_a260d_row4_col2, #T_a260d_row4_col4, #T_a260d_row4_col5, #T_a260d_row4_col6, #T_a260d_row4_col7, #T_a260d_row8_col0, #T_a260d_row10_col1, #T_a260d_row10_col2, #T_a260d_row10_col6, #T_a260d_row10_col7, #T_a260d_row11_col1, #T_a260d_row11_col2, #T_a260d_row11_col3, #T_a260d_row11_col4, #T_a260d_row11_col5, #T_a260d_row11_col6, #T_a260d_row11_col7 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_a260d_row3_col0, #T_a260d_row5_col3 {
#   background-color: #f5fbee;
#   color: #000000;
# }
# #T_a260d_row3_col1 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_a260d_row3_col2 {
#   background-color: #e4f4de;
#   color: #000000;
# }
# #T_a260d_row3_col3 {
#   background-color: #99d7ba;
#   color: #000000;
# }
# #T_a260d_row3_col4 {
#   background-color: #d0ecc9;
#   color: #000000;
# }
# #T_a260d_row3_col5 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_a260d_row3_col6 {
#   background-color: #dcf1d7;
#   color: #000000;
# }
# #T_a260d_row3_col7, #T_a260d_row9_col1 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_a260d_row5_col0 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_a260d_row5_col1 {
#   background-color: #eef9e8;
#   color: #000000;
# }
# #T_a260d_row5_col2, #T_a260d_row5_col5, #T_a260d_row5_col7, #T_a260d_row8_col7 {
#   background-color: #f0f9e9;
#   color: #000000;
# }
# #T_a260d_row5_col6, #T_a260d_row9_col2 {
#   background-color: #eff9e9;
#   color: #000000;
# }
# #T_a260d_row6_col0, #T_a260d_row7_col0 {
#   background-color: #d1edca;
#   color: #000000;
# }
# #T_a260d_row6_col4 {
#   background-color: #1d7eb7;
#   color: #f1f1f1;
# }
# #T_a260d_row6_col5 {
#   background-color: #3192c1;
#   color: #f1f1f1;
# }
# #T_a260d_row6_col6 {
#   background-color: #298abd;
#   color: #f1f1f1;
# }
# #T_a260d_row7_col1, #T_a260d_row8_col1, #T_a260d_row8_col5 {
#   background-color: #ecf8e6;
#   color: #000000;
# }
# #T_a260d_row7_col3 {
#   background-color: #e6f6e1;
#   color: #000000;
# }
# #T_a260d_row7_col4 {
#   background-color: #eaf7e4;
#   color: #000000;
# }
# #T_a260d_row7_col5 {
#   background-color: #ebf7e5;
#   color: #000000;
# }
# #T_a260d_row7_col6, #T_a260d_row8_col6 {
#   background-color: #edf8e7;
#   color: #000000;
# }
# #T_a260d_row7_col7 {
#   background-color: #f1faeb;
#   color: #000000;
# }
# #T_a260d_row8_col3 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_a260d_row8_col4 {
#   background-color: #e9f7e3;
#   color: #000000;
# }
# #T_a260d_row9_col0 {
#   background-color: #08599c;
#   color: #f1f1f1;
# }
# #T_a260d_row9_col3 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_a260d_row9_col4 {
#   background-color: #d8f0d3;
#   color: #000000;
# }
# #T_a260d_row9_col6 {
#   background-color: #e1f4dc;
#   color: #000000;
# }
# #T_a260d_row9_col7 {
#   background-color: #eef8e7;
#   color: #000000;
# }
# #T_a260d_row10_col0 {
#   background-color: #084485;
#   color: #f1f1f1;
# }
# #T_a260d_row10_col4 {
#   background-color: #f6fbef;
#   color: #000000;
# }
# #T_a260d_row11_col0 {
#   background-color: #084e90;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a260d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a260d_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_a260d_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_a260d_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_a260d_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_a260d_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_a260d_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_a260d_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_a260d_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a260d_level0_row0" class="row_heading level0 row0" >N_Days</th>
#       <td id="T_a260d_row0_col0" class="data row0 col0" >418.000000</td>
#       <td id="T_a260d_row0_col1" class="data row0 col1" >1917.782297</td>
#       <td id="T_a260d_row0_col2" class="data row0 col2" >1104.672992</td>
#       <td id="T_a260d_row0_col3" class="data row0 col3" >41.000000</td>
#       <td id="T_a260d_row0_col4" class="data row0 col4" >1092.750000</td>
#       <td id="T_a260d_row0_col5" class="data row0 col5" >1730.000000</td>
#       <td id="T_a260d_row0_col6" class="data row0 col6" >2613.500000</td>
#       <td id="T_a260d_row0_col7" class="data row0 col7" >4795.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a260d_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_a260d_row1_col0" class="data row1 col0" >418.000000</td>
#       <td id="T_a260d_row1_col1" class="data row1 col1" >50.382775</td>
#       <td id="T_a260d_row1_col2" class="data row1 col2" >10.481084</td>
#       <td id="T_a260d_row1_col3" class="data row1 col3" >26.000000</td>
#       <td id="T_a260d_row1_col4" class="data row1 col4" >42.000000</td>
#       <td id="T_a260d_row1_col5" class="data row1 col5" >51.000000</td>
#       <td id="T_a260d_row1_col6" class="data row1 col6" >58.000000</td>
#       <td id="T_a260d_row1_col7" class="data row1 col7" >78.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a260d_level0_row2" class="row_heading level0 row2" >Bilirubin</th>
#       <td id="T_a260d_row2_col0" class="data row2 col0" >418.000000</td>
#       <td id="T_a260d_row2_col1" class="data row2 col1" >3.220813</td>
#       <td id="T_a260d_row2_col2" class="data row2 col2" >4.407506</td>
#       <td id="T_a260d_row2_col3" class="data row2 col3" >0.300000</td>
#       <td id="T_a260d_row2_col4" class="data row2 col4" >0.800000</td>
#       <td id="T_a260d_row2_col5" class="data row2 col5" >1.400000</td>
#       <td id="T_a260d_row2_col6" class="data row2 col6" >3.400000</td>
#       <td id="T_a260d_row2_col7" class="data row2 col7" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a260d_level0_row3" class="row_heading level0 row3" >Cholesterol</th>
#       <td id="T_a260d_row3_col0" class="data row3 col0" >284.000000</td>
#       <td id="T_a260d_row3_col1" class="data row3 col1" >369.510563</td>
#       <td id="T_a260d_row3_col2" class="data row3 col2" >231.944545</td>
#       <td id="T_a260d_row3_col3" class="data row3 col3" >120.000000</td>
#       <td id="T_a260d_row3_col4" class="data row3 col4" >249.500000</td>
#       <td id="T_a260d_row3_col5" class="data row3 col5" >309.500000</td>
#       <td id="T_a260d_row3_col6" class="data row3 col6" >400.000000</td>
#       <td id="T_a260d_row3_col7" class="data row3 col7" >1775.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a260d_level0_row4" class="row_heading level0 row4" >Albumin</th>
#       <td id="T_a260d_row4_col0" class="data row4 col0" >418.000000</td>
#       <td id="T_a260d_row4_col1" class="data row4 col1" >3.497440</td>
#       <td id="T_a260d_row4_col2" class="data row4 col2" >0.424972</td>
#       <td id="T_a260d_row4_col3" class="data row4 col3" >1.960000</td

# %%
# Checking for % of Missing Values
df.isnull().sum()
# Out:
# N_Days             0
# Status             0
# Drug             106
# Age                0
# Sex                0
# Ascites          106
# Hepatomegaly     106
# Spiders          106
# Edema              0
# Bilirubin          0
# Cholesterol      134
# Albumin            0
# Copper           108
# Alk_Phos         106
# SGOT             106
# Tryglicerides    136
# Platelets         11
# Prothrombin        2
# Stage              6
# dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.heatmap(df.isnull(),cmap='BuPu',vmin=0.5, vmax=1)
# Out:
# <AxesSubplot:>

# %%
count_null = 0
len_df = 0
for col in df.columns:
    null = 0
    l = 0
    null = df[col].isnull().sum()
    l = len(df[col])
    count_null=count_null + null
    len_df = len_df + l
print('Percentage of missing Values: ', np.ceil(100*count_null/len_df))
# Out:
# Percentage of missing Values:  14.0

# %%
df_missing_values = pd.DataFrame({'percentage':round((df.isnull().mean())*100,4)})      
df_missing_values.sort_values(by = 'percentage', ascending = False).style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_5ccf2_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_5ccf2_row1_col0 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_5ccf2_row2_col0 {
#   background-color: #cbe566;
#   color: #000000;
# }
# #T_5ccf2_row3_col0, #T_5ccf2_row4_col0, #T_5ccf2_row5_col0, #T_5ccf2_row6_col0, #T_5ccf2_row7_col0, #T_5ccf2_row8_col0 {
#   background-color: #c7e366;
#   color: #000000;
# }
# #T_5ccf2_row9_col0 {
#   background-color: #148a66;
#   color: #f1f1f1;
# }
# #T_5ccf2_row10_col0 {
#   background-color: #0b8566;
#   color: #f1f1f1;
# }
# #T_5ccf2_row11_col0 {
#   background-color: #038166;
#   color: #f1f1f1;
# }
# #T_5ccf2_row12_col0, #T_5ccf2_row13_col0, #T_5ccf2_row14_col0, #T_5ccf2_row15_col0, #T_5ccf2_row16_col0, #T_5ccf2_row17_col0, #T_5ccf2_row18_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5ccf2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ccf2_level0_col0" class="col_heading level0 col0" >percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ccf2_level0_row0" class="row_heading level0 row0" >Tryglicerides</th>
#       <td id="T_5ccf2_row0_col0" class="data row0 col0" >32.535900</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row1" class="row_heading level0 row1" >Cholesterol</th>
#       <td id="T_5ccf2_row1_col0" class="data row1 col0" >32.057400</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row2" class="row_heading level0 row2" >Copper</th>
#       <td id="T_5ccf2_row2_col0" class="data row2 col0" >25.837300</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row3" class="row_heading level0 row3" >Drug</th>
#       <td id="T_5ccf2_row3_col0" class="data row3 col0" >25.358900</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row4" class="row_heading level0 row4" >Ascites</th>
#       <td id="T_5ccf2_row4_col0" class="data row4 col0" >25.358900</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row5" class="row_heading level0 row5" >Hepatomegaly</th>
#       <td id="T_5ccf2_row5_col0" class="data row5 col0" >25.358900</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row6" class="row_heading level0 row6" >Spiders</th>
#       <td id="T_5ccf2_row6_col0" class="data row6 col0" >25.358900</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row7" class="row_heading level0 row7" >SGOT</th>
#       <td id="T_5ccf2_row7_col0" class="data row7 col0" >25.358900</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row8" class="row_heading level0 row8" >Alk_Phos</th>
#       <td id="T_5ccf2_row8_col0" class="data row8 col0" >25.358900</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row9" class="row_heading level0 row9" >Platelets</th>
#       <td id="T_5ccf2_row9_col0" class="data row9 col0" >2.631600</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row10" class="row_heading level0 row10" >Stage</th>
#       <td id="T_5ccf2_row10_col0" class="data row10 col0" >1.435400</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row11" class="row_heading level0 row11" >Prothrombin</th>
#       <td id="T_5ccf2_row11_col0" class="data row11 col0" >0.478500</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row12" class="row_heading level0 row12" >N_Days</th>
#       <td id="T_5ccf2_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row13" class="row_heading level0 row13" >Albumin</th>
#       <td id="T_5ccf2_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row14" class="row_heading level0 row14" >Status</th>
#       <td id="T_5ccf2_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row15" class="row_heading level0 row15" >Edema</th>
#       <td id="T_5ccf2_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row16" class="row_heading level0 row16" >Sex</th>
#       <td id="T_5ccf2_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row17" class="row_heading level0 row17" >Age</th>
#       <td id="T_5ccf2_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5ccf2_level0_row18" class="row_heading level0 row18" >Bilirubin</th>
#       <td id="T_5ccf2_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
categorical_col = df.select_dtypes(["object"]).columns
numerical_col = df.select_dtypes(["float64","int64"]).columns

# %%
for j in categorical_col:
    df[j].fillna(df[j].mode().values[0], inplace=True)

# %%
for j in numerical_col:
    df[j].fillna(df[j].median(), inplace=True)
df.isnull().sum()
# Out:
# N_Days           0
# Status           0
# Drug             0
# Age              0
# Sex              0
# Ascites          0
# Hepatomegaly     0
# Spiders          0
# Edema            0
# Bilirubin        0
# Cholesterol      0
# Albumin          0
# Copper           0
# Alk_Phos         0
# SGOT             0
# Tryglicerides    0
# Platelets        0
# Prothrombin      0
# Stage            0
# dtype: int64

# %%
# As we can see there are some null values in target(stage) feature lets drop it
df.drop(df[df['Stage'].isnull()].index, inplace=True)

# %%
print("Shape of dataset after handlig null values",df.shape)
df
# Out:
# Shape of dataset after handlig null values (418, 19)
#      N_Days Status             Drug  Age Sex Ascites Hepatomegaly Spiders  \
# 0       400      D  D-penicillamine   58   F       Y            Y       Y
# 1      4500      C  D-penicillamine   56   F       N            Y       Y
# 2      1012      D  D-penicillamine   70   M       N            N       N
# 3      1925      D  D-penicillamine   54   F       N            Y       Y
# 4      1504     CL          Placebo   38   F       N            Y       Y
# ..      ...    ...              ...  ...  ..     ...          ...     ...
# 413     681      D  D-penicillamine   67   F       N            Y       N
# 414    1103      C  D-penicillamine   39   F       N            Y       N
# 415    1055      C  D-penicillamine   57   F       N            Y       N
# 416     691      C  D-penicillamine   58   F       N            Y       N
# 417     976      C  D-penicillamine   53   F       N            Y       N
#
#     Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0       Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1       N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2       S        1.4        176.0     3.48   210.0     516.0   96.10
# 3       S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4       N        3.4        279.0     3.53   143.0     671.0  113.15
# ..    ...        ...          ...      ...     ...       ...     ...
# 413     N        1.2        309.5     2.96    73.0    1259.0  114.70
# 414     N        0.9        309.5     3.83    73.0    1259.0  114.70
# 415     N        1.6        309.5     3.42    73.0    1259.0  114.70
# 416     N        0.8        309.5     3.75    73.0    1259.0  114.70
# 417     N        0.7        309.5     3.29    73.0    1259.0  114.70
#
#      Tryglicerides  Platelets  Prothrombin  Stage
# 0            172.0      190.0         12.2    4.0
# 1             88.0      221.0         10.6    3.0
# 2             55.0      151.0         12.0    4.0
# 3             92.0      183.0         10.3    4.0
# 4             72.0      136.0         10.9    3.0
# ..             ...        ...          ...    ...
# 413          108.0      174.0         10.9    3.0
# 414          108.0      180.0         11.2    4.0
# 415          108.0      143.0          9.9    3.0
# 416          108.0      269.0         10.4    3.0
# 417          108.0      350.0         10.6    4.0
#
# [418 rows x 19 columns]

# %%
numerical_col[:-1]       # Columns contain numerical variable except stage
# Out:
# Index(['N_Days', 'Age', 'Bilirubin', 'Cholesterol', 'Albumin', 'Copper',
#        'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin'],
#       dtype='object')

# %%
titles = numerical_col[:-1].tolist()
plt.figure(figsize=(12,8))
for i, variable in enumerate(numerical_col[:-1]):
    plt.subplot(4,3,i+1)
    sns.set_palette('Set2')
    sns.boxplot(x=df[variable],data=df,orient="v")
    sns.despine(top=True,right=True,left=True)
    plt.tight_layout()
    plt.title(titles[i],size = 18)

# %%
for col in numerical_col:
    q3=df[col].quantile(0.75).round(4)
    q1=df[col].quantile(0.25).round(4)
    upper_lim = round(q3 + 1.5*(q3-q1),4)
    lower_lim = round(q1 - 1.5*(q3-q1),4)
    df = df[(df[col] < upper_lim) & (df[col] > lower_lim)]
df.shape
# Out:
# (163, 19)

# %%
# boxplot after dealing with outliers
titles = numerical_col[:-1].tolist()
plt.figure(figsize=(12,8))
for i, variable in enumerate(numerical_col[:-1]):
    plt.subplot(4,3,i+1)
    sns.set_palette('Set2')
    sns.boxplot(x=df[variable],data=df,orient="v")
    sns.despine(top=True,right=True,left=True)
    plt.tight_layout()
    plt.title(titles[i],size = 18)

# %%
#  correlation between features and with target, ignore ID column
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), cmap="RdBu", annot=True)
# Out:
# <AxesSubplot:>

# %%
# we want 2 target values instead of 4
# 0 means no cirrhosis
# 1 means cirrhosis
#replace stage 4 as 1(positive) and rest of the stages in to 0(negative)
df['Stage'] = np.where(df['Stage'] == 4,1,0)
df.shape
# Out:
# (163, 19)

# %%
df[df['Stage']==0]
# Out:
#      N_Days Status             Drug  Age Sex Ascites Hepatomegaly Spiders  \
# 18     4232      C  D-penicillamine   49   F       N            Y       N
# 35     3611      C          Placebo   56   F       N            N       N
# 44     4025      C          Placebo   41   F       N            N       N
# 64     3992      C  D-penicillamine   40   F       N            N       N
# 71     4184      C          Placebo   32   F       N            N       N
# ..      ...    ...              ...  ...  ..     ...          ...     ...
# 411    1097      C  D-penicillamine   67   F       N            Y       N
# 412     989      C  D-penicillamine   35   F       N            Y       N
# 413     681      D  D-penicillamine   67   F       N            Y       N
# 415    1055      C  D-penicillamine   57   F       N            Y       N
# 416     691      C  D-penicillamine   58   F       N            Y       N
#
#     Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 18      S        0.7        235.0     3.56    39.0    1881.0   93.00
# 35      N        0.3        172.0     3.39    18.0     558.0   71.30
# 44      N        0.6        309.5     3.93    19.0    1826.0   71.30
# 64      N        1.2        256.0     3.60    74.0     724.0  141.05
# 71      N        0.5        320.0     3.54    51.0    1243.0  122.45
# ..    ...        ...          ...      ...     ...       ...     ...
# 411     N        1.0        309.5     3.58    73.0    1259.0  114.70
# 412     N        0.7        309.5     3.23    73.0    1259.0  114.70
# 413     N        1.2        309.5     2.96    73.0    1259.0  114.70
# 415     N        1.6        309.5     3.42    73.0    1259.0  114.70
# 416     N        0.8        309.5     3.75    73.0    1259.0  114.70
#
#      Tryglicerides  Platelets  Prothrombin  Stage
# 18           123.0      209.0         11.0      0
# 35            96.0      311.0         10.6      0
# 44           108.0      474.0         10.9      0
# 64           108.0      430.0         10.0      0
# 71            80.0      225.0         10.0      0
# ..             ...        ...          ...    ...
# 411          108.0      244.0         10.8      0
# 412          108.0      312.0         10.8      0
# 413          108.0      174.0         10.9      0
# 415          108.0      143.0          9.9      0
# 416          108.0      269.0         10.4      0
#
# [113 rows x 19 columns]

# %%
for i in categorical_col:
    print(df[i])
    print('----------------------------------')
# Out:
# 10     D
# 18     C
# 20     C
# 35     C
# 37     D
#       ..
# 413    D
# 414    C
# 415    C
# 416    C
# 417    C
# Name: Status, Length: 163, dtype: object
# ----------------------------------
# 10             Placebo
# 18     D-penicillamine
# 20             Placebo
# 35             Placebo
# 37             Placebo
#             ...
# 413    D-penicillamine
# 414    D-penicillamine
# 415    D-penicillamine
# 416    D-penicillamine
# 417    D-penicillamine
# Name: Drug, Length: 163, dtype: object
# ----------------------------------
# 10     F
# 18     F
# 20     M
# 35     F
# 37     F
#       ..
# 413    F
# 414    F
# 415    F
# 416    F
# 417    F
# Name: Sex, Length: 163, dtype: object
# ----------------------------------
# 10     N
# 18     N
# 20     N
# 35     N
# 37     N
#       ..
# 413    N
# 414    N
# 415    N
# 416    N
# 417    N
# Name: Ascites, Length: 163, dtype: object
# ----------------------------------
# 10     Y
# 18     Y
# 20     Y
# 35     N
# 37     Y
#       ..
# 413    Y
# 414    Y
# 415    Y
# 416    Y
# 417    Y
# Name: Hepatomegaly, Length: 163, dtype: object
# ----------------------------------
# 10     Y
# 18     N
# 20     Y
# 35     N
# 37     Y
#       ..
# 413    N
# 414    N
# 415    N
# 416    N
# 417    N
# Name: Spiders, Length: 163, dtype: object
# ----------------------------------
# 10     N
# 18     S
# 20     N
# 35     N
# 37     N
#       ..
# 413    N
# 414    N
# 415    N
# 416    N
# 417    N
# Name: Edema, Length: 163, dtype: object
# ----------------------------------

# %%
for i in categorical_col:
    print(df.groupby(i).Stage.value_counts())
    print('----------------------------------')
# Out:
# Status  Stage
# C       0        94
#         1        25
# CL      0         4
#         1         2
# D       1        23
#         0        15
# Name: Stage, dtype: int64
# ----------------------------------
# Drug             Stage
# D-penicillamine  0        90
#                  1        37
# Placebo          0        23
#                  1        13
# Name: Stage, dtype: int64
# ----------------------------------
# Sex  Stage
# F    0        108
#      1         44
# M    1          6
#      0          5
# Name: Stage, dtype: int64
# ----------------------------------
# Ascites  Stage
# N        0        112
#          1         49
# Y        0          1
#          1          1
# Name: Stage, dtype: int64
# ----------------------------------
# Hepatomegaly  Stage
# N             0        38
#               1         6
# Y             0        75
#               1        44
# Name: Stage, dtype: int64
# ----------------------------------
# Spiders  Stage
# N        0        102
#          1         40
# Y        0         11
#          1         10
# Name: Stage, dtype: int64
# ----------------------------------
# Edema  Stage
# N      0        105
#        1         38
# S      1         11
#        0          8
# Y      1          1
# Name: Stage, dtype: int64
# ----------------------------------

# %%
for i in categorical_col:
    sns.countplot(x=df[i], hue='Stage', data =df)
    plt.show()

# %%
pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.22.0-py2.py3-none-any.whl (1.4 MB)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\msska\apps\anaconda fold\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\msska\apps\anaconda fold\lib\site-packages (from mlxtend) (3.5.1)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\msska\apps\anaconda fold\lib\site-packages (from mlxtend) (1.7.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\msska\apps\anaconda fold\lib\site-packages (from mlxtend) (1.21.5)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\msska\apps\anaconda fold\lib\site-packages (from mlxtend) (1.1.2)
# Requirement already satisfied: setuptools in c:\users\msska\apps\anaconda fold\lib\site-packages (from mlxtend) (61.2.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\msska\apps\anaconda fold\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\msska\apps\anaconda fold\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\msska\apps\anaconda fold\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\msska\apps\anaconda fold\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\msska\apps\anaconda fold\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\msska\apps\anaconda fold\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\msska\apps\anaconda fold\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: packaging>=20.0 in c:\users\msska\apps\anaconda fold\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
#
# Requirement already satisfied: pytz>=2020.1 in c:\users\msska\apps\anaconda fold\lib\site-packages (from pandas>=0.24.2->mlxtend) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\msska\apps\anaconda fold\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\msska\apps\anaconda fold\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.22.0

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.feature_selection import SelectKBest
from sklearn.utils import resample
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, classification_report
import warnings
warnings.filterwarnings('ignore')
from sklearn import metrics

# %%
features= df.copy()
features.head()
# Out:
#     N_Days Status             Drug  Age Sex Ascites Hepatomegaly Spiders  \
# 10    3762      D          Placebo   53   F       N            Y       Y
# 18    4232      C  D-penicillamine   49   F       N            Y       N
# 20    3445      C          Placebo   64   M       N            Y       Y
# 35    3611      C          Placebo   56   F       N            N       N
# 37    3244      D          Placebo   36   F       N            Y       Y
#
#    Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 10     N        1.4        259.0     4.16    46.0    1104.0   79.05
# 18     S        0.7        235.0     3.56    39.0    1881.0   93.00
# 20     N        0.6        252.0     3.83    41.0     843.0   65.10
# 35     N        0.3        172.0     3.39    18.0     558.0   71.30
# 37     N        3.3        383.0     3.53   102.0    1234.0  137.95
#
#     Tryglicerides  Platelets  Prothrombin  Stage
# 10           79.0      258.0         12.0      1
# 18          123.0      209.0         11.0      0
# 20           83.0      336.0         11.4      1
# 35           96.0      311.0         10.6      0
# 37           87.0      234.0         11.0      1

# %%
one_hot_encoded_training_predictors = pd.get_dummies(features)
data=one_hot_encoded_training_predictors

# %%
y = df.loc[:,'Stage'].values # target
X = data.drop(['Stage'], axis = 1)  # predictor
print("X - ", X.shape, "\ny - ", y.shape)
# Out:
# X -  (163, 27)
# y -  (163,)

# %%
best=SelectKBest(score_func=chi2, k=6)
fit=best.fit(X,y)

# %%
data_scores=pd.DataFrame(fit.scores_)
data_columns=pd.DataFrame(X.columns)

# %%
scores=pd.concat([data_columns,data_scores],axis=1)
scores.columns=['Feature','Score']
print(scores.nlargest(11,'Score'))
# Out:
#            Feature        Score
# 0           N_Days  2915.116903
# 9        Platelets   131.810580
# 5           Copper    27.141961
# 1              Age    25.811006
# 13        Status_D    15.923619
# 25         Edema_S     6.619925
# 20  Hepatomegaly_N     6.006774
# 2        Bilirubin     5.909271
# 11        Status_C     5.228861
# 3      Cholesterol     4.879978
# 17           Sex_M     2.947450

# %%
train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.2, random_state=1,shuffle=True)

# %%
from sklearn.linear_model import LogisticRegression
m1 = 'LogisticRegression'
lr = LogisticRegression(random_state=1, max_iter=1000)
model = lr.fit(train_x, train_y)
lr_predict = lr.predict(test_x)
lr_conf_matrix = confusion_matrix(test_y, lr_predict)
lr_acc_score = accuracy_score(test_y, lr_predict)
print("confussion matrix")
print(lr_conf_matrix)
print("\n")
print("Accuracy of Logistic Regression:",lr_acc_score*100,'\n')
print(classification_report(test_y,lr_predict))
# Out:
# confussion matrix
# [[23  3]
#  [ 6  1]]
#
#
# Accuracy of Logistic Regression: 72.72727272727273
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.84        26
#            1       0.25      0.14      0.18         7
#
#     accuracy                           0.73        33
#    macro avg       0.52      0.51      0.51        33
# weighted avg       0.68      0.73      0.70        33

# %%
plot_confusion_matrix(confusion_matrix(test_y, lr_predict), cmap = "viridis_r")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)

# %%
m2 = 'Random Forest Classfier'
rf = RandomForestClassifier(n_estimators=200, random_state=0,max_depth=12)
rf.fit(train_x,train_y)
rf_predicted = rf.predict(test_x)
rf_conf_matrix = confusion_matrix(test_y, rf_predicted,labels=(1,0))
rf_acc_score = accuracy_score(test_y, rf_predicted)
print("confussion matrix")
print(rf_conf_matrix)
print("\n")
print("Accuracy of Random Forest:",rf_acc_score*100,'\n')
print(classification_report(test_y,rf_predicted))
# Out:
# confussion matrix
# [[ 3  4]
#  [ 2 24]]
#
#
# Accuracy of Random Forest: 81.81818181818183
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89        26
#            1       0.60      0.43      0.50         7
#
#     accuracy                           0.82        33
#    macro avg       0.73      0.68      0.69        33
# weighted avg       0.80      0.82      0.81        33

# %%
#confusion matrix
plot_confusion_matrix(confusion_matrix(test_y, rf_predicted), cmap = "viridis_r")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)
